# %% [markdown]
# Map RERB

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
RERB=geopandas.read_file(r'C:\Users\morga\Documents\GitHub\MLPython\dataviz\brut\RERB\traces-du-reseau-ferre-idf.shp')

# %%
RERB=RERB[RERB.res_com=='RER B']

# %%
RERB
# Out:
#       objectid idrefliga idrefligc indice_lig res_com reseau mode  fer  train  \
# 5         28.0    A01857    C01743          B   RER B  RER B  RER  1.0    0.0
# 6         32.0    A01857    C01743          B   RER B  RER B  RER  1.0    0.0
# 9         49.0    A01857    C01743          B   RER B  RER B  RER  1.0    0.0
# 49       235.0    A01857    C01743          B   RER B  RER B  RER  1.0    0.0
# 50       239.0    A01857    C01743          B   RER B  RER B  RER  1.0    0.0
# 76       348.0    A01857    C01743          B   RER B  RER B  RER  1.0    0.0
# 205      988.0    A01857    C01743          B   RER B  RER B  RER  1.0    0.0
# 244     1140.0    A01857    C01743          B   RER B  RER B  RER  1.0    0.0
# 361       12.0    A01857    C01743          B   RER B  RER B  RER  1.0    0.0
# 365       29.0    A01857    C01743          B   RER B  RER B  RER  1.0    0.0
# 366       33.0    A01857    C01743          B   RER B  RER B  RER  1.0    0.0
# ...

# %%
RERB.plot()

# %%
import mapclassify
import numpy as np
import geopandas
import geoplot
import geoplot.crs as gcrs
import matplotlib.pyplot as plt
import os
ax = geoplot.webmap(RERB, projection=gcrs.WebMercator(),figsize=(10, 10))
geoplot.polyplot(RERB, color='blue',
linewidth=100,ax=ax)
RERB.plot(ax=ax,linewidth=100)

# %%
RERB_geo = geopandas.GeoDataFrame(
    RERB, geometry=geopandas.points_from_xy(RERB.long, RERB.lat))
RERB_geo = RERB_geo.set_geometry('geometry')

# %%
RERB_geo.plot()

# %%
from shapely.geometry import Point, LineString, shape

geometry = [Point(xy) for xy in zip(RERB.long, RERB.lat)]
geo_df = geopandas.GeoDataFrame(RERB, geometry=geometry)

# %%
geo_df2 = geo_df.groupby(['Code INSEE'])['geometry'].apply(lambda x:LineString(x.tolist()))
geo_df2 = gpd.GeoDataFrame(geo_df2, geometry='geometry')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\shapely\speedups\_speedups.pyx in shapely.speedups._speedups.geos_linestring_from_py()
#
# AttributeError: 'list' object has no attribute '__array_interface__'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-7c549458620c> in <module>
# ----> 1 geo_df2 = geo_df.groupby(['Code INSEE'])['geometry'].apply(lambda x:                 LineString(x.tolist()))
#       2 geo_df2 = gpd.GeoDataFrame(geo_df2, geometry='geometry')
#       3
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in apply(self, func, *args, **kwargs)
#     222     )
#     223     def apply(self, func, *args, **kwargs):
# --> 224         return super().apply(func, *args, **kwargs)
#     225
# ...

# %%
RERB.plot(figsize=(14,10))

# %%
import mapclassify
import numpy as np
import geopandas
import geoplot
import geoplot.crs as gcrs
import matplotlib.pyplot as plt
import os
import folium
ax=geoplot.webmap(RERB, projection=gcrs.WebMercator(),figsize=(10, 10))
geolines(RERB,linewidth=10,color='blue',ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-126-e28300df600d> in <module>
#       6 import matplotlib.pyplot as plt
#       7 import os
# ----> 8 import folium
#       9 ax=geoplot.webmap(RERB, projection=gcrs.WebMercator(),figsize=(10, 10))
#      10 geolines(RERB,linewidth=10,color='blue',ax=ax)
#
# ModuleNotFoundError: No module named 'folium'

# %%
    data_geo_centroid = data_geo.dropna().copy()
    data_geo_centroid["geometry"] = data_geo_centroid["geometry"].centroid
    
    geoplot.pointplot(
    data_geo_centroid, ax = ax, scale = 'variable',
    hue = 'variable', scheme=scheme, cmap='RdBu_r', edgecolor='None', limits=(4, 4),legend=True, legend_var='hue',
    legend_kwargs={'frameon': True, 'loc': 'lower right','fontsize':'medium','framealpha':1},
    legend_labels=['Q1', 'Q2', 'Q3', 'Q4', 'Q5','Q6','Q7','Q8','Q9','Q10']
    )
    
    ax.set_title(titre, fontsize=20)

# %%
import contextily as ctx
ax = RERB_geo.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
ctx.add_basemap(ax)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\contextily\tile.py in _retryer(tile_url, wait, max_retries)
#     370         request = requests.get(tile_url, headers={"user-agent": USER_AGENT})
# --> 371         request.raise_for_status()
#     372     except requests.HTTPError:
#
# ~\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 404 Client Error: Not Found for url: https://stamen-tiles-a.a.ssl.fastly.net/terrain/28/134217741/134217399.png
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-39-79c78bc9bde9> in <module>
#       1 import contextily as ctx
# ...
